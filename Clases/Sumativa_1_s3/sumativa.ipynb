# %%
# Imports necesarios.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Base de datos local
data = sns.load_dataset("car_crashes")
data.head() # Cabecera de los datos.
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# **Pregunta 1**
#
# Realice un **filtro** al conjunto de datos para incluir solo aquellos estados en donde la tasa total de accidentes (variable "total") es mayor que la media de todos los estados.

# %%
media_total_accidentes = data["total"].mean() # Calcular la media de la variable "Total"

# %%
filtro1 = data[data["total"] > media_total_accidentes] # Filtrar todos los valores de la columna "Total" que son mayores que su media.
filtro1
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# 16   17.8     4.806    4.272          13.706       15.130       780.45
# 17   21.4     4.066    4.922          16.692       16.264       872.51
# 18   20.5     7.175    6.765          14.965       20.090      1281.55
# 24   17.6     2.640    5.456           1.760       17.600       896.07
# 25   16.1     6.923    5.474          14.812       13.524       790.32
# ...

# %% [markdown]
# Una vez realizada dicha acción responda:
# ¿Cuál es la **media de accidentes** en donde el **alcohol** fue un factor para los estados filtrados?

# %%
preg1 = filtro1["alcohol"].mean()
preg1
# Out:
# 6.1589583333333335

# %% [markdown]
# **Pregunta 2**
#
# Realice un filtro al conjunto de datos para seleccionar los **estados** en donde la tasa de
# accidentes por exceso de velocidad ("speeding") es menor que el primer cuartil de todas
# las tasas de "speeding".

# %%
# Cuartil 1 de la variable "speeding"
cuartil1 = data["speeding"].quantile(0.25)
cuartil1
# Out:
# 3.7664999999999997

# %%
filtro2 = data[data["speeding"]<cuartil1]
filtro2
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 14   14.5     3.625    4.205          13.775       13.775       710.46
# 15   15.7     2.669    3.925          15.229       13.659       649.06
# 21    8.2     1.886    2.870           7.134        6.560      1011.14
# 22   14.1     3.384    3.948          13.395       10.857      1110.61
# 23    9.6     2.208    2.784           8.448        8.448       777.18
# 24   17.6     2.640    5.456           1.760       17.600       896.07
# 27   14.9     1.937    5.215          13.857       13.410       732.28
# 30   11.2     1.792    3.136           9.632        8.736      1301.52
# 31   18.4     3.496    4.968          12.328       18.032       869.85
# ...

# %% [markdown]
# **Pregunta 2**
# Utilizando el filtro anterior responda ¿Cuál es la mediana de las primas de seguro
# (ins_premium) para estos estados.

# %%
preg2 = filtro2["ins_premium"].median()
preg2
# Out:
# 896.07

# %% [markdown]
# **Pregunta 3**
# Crea una nueva variable que categorice los estados como "Alcohol Alto" o "Alcohol Bajo"
# según si la tasa de accidentes relacionados con **alcohol** está por encima o por debajo de la
# mediana.

# %%
mediana_alcohol = data["alcohol"].median()

# %%
def asignar_rango(alcohol):
    if alcohol > mediana_alcohol:
        return "Alto_Alcohol"
    else:
        return "Bajo_Alcohol"

# %% [markdown]
# En base a esto responde ¿Cuál es la desviación estándar de las pérdidas aseguradas
# ("ins_losses") en la categoriua "Alcohol Alto"?

# %%
data["alcohol_rango"] = data["alcohol"].apply(asignar_rango)
data.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev alcohol_rango
# 0      145.08     AL  Alto_Alcohol
# 1      133.93     AK  Bajo_Alcohol
# 2      110.35     AZ  Alto_Alcohol
# 3      142.39     AR  Alto_Alcohol
# 4      165.63     CA  Bajo_Alcohol

# %%
data.groupby("alcohol_rango")["ins_losses"].std() #std() es la desviación estandar.
# Out:
# alcohol_rango
# Alto_Alcohol    24.689203
# Bajo_Alcohol    25.325266
# Name: ins_losses, dtype: float64

# %%
print(f"Respuesta: Alto_Alcohol = {round(24.689203,2)}")
# Out:
# Respuesta: Alto_Alcohol = 24.69

# %% [markdown]
# **Pregunta 4**
# Cargar una archivo en formato png con el histograma de la variable "total".

# %%
sns.histplot(data = data, x="total")
plt.title("Histograma de la variable Total")
plt.savefig("histograma.png", dpi=300)
plt.show()
